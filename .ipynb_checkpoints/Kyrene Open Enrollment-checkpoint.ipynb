# %% [markdown]
# ## Last updated Dec 28, 2023

# %%
import pandas as pd
import numpy as np
import os
import geopandas as gpd

os.getlogin()
# Out:
# 'matto'

# %%
path = r"C:\Users\matto\Desktop\School Choice"
data = os.path.join(path, "Data")

zip_path = os.path.join(data, "tl_2020_us_zcta520") 
district_shape_path = os.path.join(data, "TL_2022_SD") 

output = os.path.join(path, "Output")

# %% [markdown]
# ## CTD ADM Dictionary

# %%
ctd_adm = pd.read_csv(os.path.join(data, "SchoolInfo.csv"))
ctd_adm_grade_dict = dict(zip(ctd_adm['EntityID'], ctd_adm['Grades']))
ctd_adm_type_dict = dict(zip(ctd_adm['EntityID'], ctd_adm['Entity_Type']))
ctd_adm_name_dict = dict(zip(ctd_adm['EntityID'], ctd_adm['Name']))

# %%
ctds_adm = pd.read_csv(os.path.join(data, "CTDS_ADM_FY_22.csv"))
ctds_adm_grade_dict = dict(zip(ctd_adm['EntityID'], ctd_adm['Grades']))
ctds_adm_type_dict = dict(zip(ctd_adm['EntityID'], ctd_adm['Entity_Type']))
ctds_adm_name_dict = dict(zip(ctd_adm['EntityID'], ctd_adm['Name']))

# %%
letter = pd.ExcelFile(os.path.join(data, "FY20Combined20Public202023-06-26.xlsx"))
letter.sheet_names

grades = pd.DataFrame()

for sheet in ['Traditional K-8 Schools','Traditional 9-12 Schools','Traditional Hybrid Schools','Alternative Schools']:
    temp = pd.read_excel(os.path.join(data, "FY20Combined20Public202023-06-26.xlsx"), sheet_name = sheet)
    temp = temp[['School Name','School Code','Letter Grade','Model']]
    grades = pd.concat([grades, temp])

# %%
letter_grade_dict = dict(zip(grades['School Code'], grades['Letter Grade']))

# %% [markdown]
# ## ELSI

# %%
edge = pd.read_csv(os.path.join(data,"ELSI_csv_export_6383927981376258893363.csv"), 
                   skiprows = 6)

edge.drop(columns = ['School Name'], inplace = True)

edge.columns = [c.replace("[Public School] Latest available year","") for c in edge.columns]
edge.columns = [c.replace("[Public School] 2021-22","") for c in edge.columns]
edge.columns = [c.replace("(SY 2017-18 onward) ","") for c in edge.columns]
edge.columns = [c.strip() for c in edge.columns]

edge['LEAID'] = edge['State School ID'].str.split("-").str[-2]
edge['State School ID'] = edge['State School ID'].str.split("-").str[-1]

edge = edge[edge['State School ID'].notnull()]

edge['LEA Type'] = edge['LEAID'].astype(int).map(ctd_adm_type_dict)
edge['LEA Grade'] = edge['LEAID'].astype(int).map(ctd_adm_grade_dict)
edge['LEA Name'] = edge['LEAID'].astype(int).map(ctd_adm_name_dict)

edge['Letter'] = edge['State School ID'].astype(int).map(letter_grade_dict)

edge_gdf = gpd.GeoDataFrame(edge, geometry = gpd.points_from_xy(edge.Longitude, edge.Latitude))
edge_gdf.set_crs("EPSG:4269", inplace = True)
edge_gdf
# Out:
#      State Name                                 School Name  \
# 0       Arizona              A J Mitchell Elementary School
# 1       ARIZONA                          A+ Charter Schools
# 2       Arizona                                    A. C. E.
# 3       Arizona                      AAEC - Paradise Valley
# 4       Arizona                          AAEC - SMCC Campus
# ...         ...                                         ...
# 2501    ARIZONA  Yuma District One Digital Learning Academy
# 2502    Arizona                            Yuma High School
# 2503    Arizona                Yuma Online Distance Academy
# 2504    Arizona                          Zaharis Elementary
# 2505    Arizona                Zuni Hills Elementary School
#
#       School ID - NCES Assigned   Latitude   Longitude State School ID  \
# 0                  4.055300e+10  31.347700 -110.938900            5958
# 1                  4.009980e+10  33.042533 -112.015895         1000972
# 2                  4.046300e+10  32.453107 -111.207690            5768
# 3                  4.001060e+10  33.654305 -112.001380            6344
# 4                  4.004170e+10  33.378982 -112.039907            5503
# ...                         ...        ...         ...             ...
# 2501               4.096000e+10  32.716311 -114.625427           92641
# 2502               4.096300e+10  32.719300 -114.629600            6189
# 2503               4.096300e+10  32.670152 -114.633814           91316
# 2504               4.049700e+10  33.455000 -111.628000           79807
# 2505               4.062500e+10  33.688000 -112.293300           79645
#
#      State Agency ID School Level    LEAID        LEA Type LEA Grade  \
# 0            AZ-4457   Elementary     4457        District    'PK-12
# 1         AZ-1000166         High  1000166  Charter Holder     '7-12
# 2            AZ-4404         High     4404        District    'PK-12
# 3            AZ-4331         High     4331  Charter Holder     '9-12
# 4           AZ-85816         High    85816  Charter Holder     '9-12
# ...              ...          ...      ...             ...       ...
# 2501         AZ-4499   Elementary     4499        District     'PK-8
# 2502         AZ-4507         High     4507        District     '9-12
# 2503         AZ-4507         High     4507        District     '9-12
# 2504         AZ-4235   Elementary     4235        District    'PK-12
# 2505         AZ-4237   Elementary     4237        District    'PK-12
#
#                                         LEA Name Letter  \
# 0                       Nogales Unified District      B
# 1                             A+ Charter Schools      B
# 2                        Marana Unified District    NaN
# 3     Arizona Agribusiness & Equine Center, Inc.      A
# 4     Arizona Agribusiness & Equine Center, Inc.      B
# ...                                          ...    ...
# 2501                    Yuma Elementary District    NaN
# 2502             Yuma Union High School District      C
# 2503             Yuma Union High School District    NaN
# 2504                       Mesa Unified District      A
# 2505              Peoria Unified School District      B
#
#                          geometry
# 0     POINT (-110.93890 31.34770)
# 1     POINT (-112.01590 33.04253)
# 2     POINT (-111.20769 32.45311)
# 3     POINT (-112.00138 33.65431)
# 4     POINT (-112.03991 33.37898)
# ...                           ...
# 2501  POINT (-114.62543 32.71631)
# 2502  POINT (-114.62960 32.71930)
# 2503  POINT (-114.63381 32.67015)
# 2504  POINT (-111.62800 33.45500)
# 2505  POINT (-112.29330 33.68800)
#
# [2506 rows x 14 columns]

# %% [markdown]
# ## Shapefile Setup

# %%
zip_shape = gpd.read_file(os.path.join(zip_path, "tl_2020_us_zcta520.shp"))
zip_shape = zip_shape.to_crs('EPSG:2223')
zip_shape['zip_area'] = zip_shape.area/2.788e+7

# %% [markdown]
# ## District Shape Files

# %%
elementary = gpd.read_file(os.path.join(district_shape_path, "TL_2022_US_SDE.shp"))
unified = gpd.read_file(os.path.join(district_shape_path, "TL_2022_US_SDU.shp"))

elementary = elementary[elementary['STATEFP'] == "04"]
unified = unified[unified['STATEFP'] == "04"]

district_shape = gpd.pd.concat([elementary, unified])
district_shape = district_shape.to_crs('EPSG:2223')
district_shape['district_area'] = district_shape.area/2.788e+7

district_intersect_zip = gpd.overlay(district_shape, zip_shape, how = 'intersection', keep_geom_type = True)
district_intersect_zip['district_intersect_zip_area'] = district_intersect_zip.area/2.788e+7
# Out:
# C:\Users\matto\anaconda3\envs\Python_3_11\Lib\site-packages\geopandas\geodataframe.py:1815: FutureWarning: `unary_union` returned None due to all-None GeoSeries. In future, `unary_union` will return 'GEOMETRYCOLLECTION EMPTY' instead.
#   merged_geom = block.unary_union

# %%
district_intersect_zip.to_crs('EPSG:4269', inplace = True)
district_intersect_zip['pct_overlap'] = district_intersect_zip['district_intersect_zip_area']/district_intersect_zip['zip_area']

# %%
district_intersect_zip.columns
# Out:
# Index(['STATEFP', 'ELSDLEA', 'GEOID', 'NAME', 'LSAD', 'LOGRADE', 'HIGRADE',
#        'MTFCC', 'SDTYP', 'FUNCSTAT', 'ALAND', 'AWATER', 'INTPTLAT', 'INTPTLON',
#        'GEO_YEAR', 'SCHOOLYEAR', 'UNSDLEA', 'district_area', 'ZCTA5CE20',
#        'GEOID20', 'CLASSFP20', 'MTFCC20', 'FUNCSTAT20', 'ALAND20', 'AWATER20',
#        'INTPTLAT20', 'INTPTLON20', 'zip_area', 'geometry',
#        'district_intersect_zip_area', 'pct_overlap'],
#       dtype='object')

# %%
district_intersect_zip.to_file(os.path.join(district_shape_path,"District_Intersect_Zip.shp"))
# Out:
# C:\Users\matto\AppData\Local\Temp\ipykernel_11228\3556926830.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   district_intersect_zip.to_file(os.path.join(district_shape_path,"District_Intersect_Zip.shp"))

# %%
# edge_gdf[edge_gdf['LEA Grade'].str.contains("12", na = False)]

# %% [markdown]
# ## Load in open enrollment data - boundary district first

# %%
df = pd.read_excel(os.path.join(data,"FY 2022 Open Enrollment Data.xlsx"), 
                   sheet_name = "School by Boundary District", skiprows = 1)

# %% [markdown]
# ## Roosevelt is 4279 and Kyrene is 4267

# %%
df[df['Boundary District ID'] == 4279].groupby(['Attending LEA Name'])['Total ADM'].sum().sort_values(ascending = False)
# Out:
# Attending LEA Name
# Roosevelt Elementary District                                                 6084.0231
# The Paideia Academies, Inc                                                     604.3039
# Laveen Elementary District                                                     485.5146
# Kyrene Elementary District                                                     470.8267
# Espiritu Community Development Corp.                                           410.0755
# Fit Kids, Inc. dba Champion Schools                                            407.2133
# Phoenix Education Management, LLC,                                             389.3511
# Tempe School District                                                          354.5465
# Morrison Education Group, Inc.                                                 331.7810
# ASU Preparatory Academy                                                        320.2242
# BASIS Charter Schools, Inc.                                                    314.9424
# EAGLE South Mountain Charter, Inc.                                             314.0366
# Phoenix Elementary District                                                    310.6550
# Legacy Traditional School – Laveen Village                                     309.1826
# Academy of Mathematics and Science South, Inc.                                 308.5103
# Kaizen Education Foundation dba South Pointe Elementary School                 234.0020
# South Phoenix Academy Inc.                                                     162.3669
# South Valley Academy, Inc.                                                     145.7374
# George Gervin Youth Center, Inc.                                               123.2560
# EAGLE College Prep Harmony, LLC                                                119.1451
# Kaizen Education Foundation dba South Pointe Junior High School                117.6139
# Friendly House, Inc.                                                           114.9578
# Portable Practical Educational Preparation, Inc. (PPEP, Inc.)                  111.1021
# Vista College Preparatory, Inc.                                                100.5545
# Washington Elementary School District                                           84.8103
# ASU Preparatory Academy Digital                                                 66.6665
# Espiritu Schools                                                                61.1675
# Valley of the Sun Waldorf Education Association, dba Desert Marigold Schoo      48.6496
# Kaizen Education Foundation dba Advance U                                       42.9500
# Arizona School For The Arts                                                     40.5487
# Heritage Academy Laveen, Inc.                                                   37.0370
# Wilson Elementary District                                                      34.0934
# Country Gardens Charter Schools                                                 31.0000
# Academy of Mathematics and Science, Inc.                                        30.9387
# Edkey, Inc. - Sequoia Choice Schools                                            30.4036
# Arizona Connections Academy Charter School, Inc.                                29.6469
# Creighton Elementary District                                                   29.3200
# Madison Elementary District                                                     25.4646
# Arizona Education Solutions                                                     24.3310
# West Valley Arts and Technology Academy, Inc.                                   23.9164
# Alhambra Elementary District                                                    22.2059
# Balsz Elementary District                                                       21.1172
# Archway Classical Academy Veritas                                               20.8302
# Arizona Autism Charter Schools, Inc.                                            20.6017
# Edkey, Inc. - Sequoia Ranch School                                              20.2500
# American Virtual Academy                                                        20.1161
# Horizon Community Learning Center, Inc.                                         19.6300
# Allen-Cochran Enterprises, Inc.                                                 14.5000
# Veritas Preparatory Academy                                                     13.0000
# Phoenix International Academy                                                   12.8712
# New World Educational Center                                                    12.1700
# Miami Unified District                                                          11.4591
# Osborn Elementary District                                                      10.4703
# Name: Total ADM, dtype: float64

# %%
df[df['Attending LEA ID'] == 4267].groupby(['Boundary District ID','Boundary District Name'])['Total ADM'].sum()
# Out:
# Boundary District ID  Boundary District Name
# 4235                  Mesa Unified District                 380.0201
# 4239                  Gilbert Unified District               46.0135
# 4241                  Paradise Valley Unified District       11.0850
# 4242                  Chandler Unified District #80         554.8292
# 4258                  Tempe School District                 608.1685
# 4267                  Kyrene Elementary District          11039.5844
# 4276                  Laveen Elementary District             61.3642
# 4279                  Roosevelt Elementary District         470.8267
# 4441                  Maricopa Unified School District      283.5810
# Other                 Other                                 745.5886
# Name: Total ADM, dtype: float64

# %% [markdown]
# ## Specify Kyrene schools with bussing

# %%
bus_list = [5303, 5304, 5301, 5305, 5299, 5298, 79143, 5311, 5318, 78923]

# %%
# df2 = df[df['Attending LEA ID'] == 4258].groupby(['School Name','School ID','Boundary District Name'])['Total ADM'].sum().unstack()

# df2['Total'] = df2.sum(axis = 1)

# df2['Not Tempe'] = df2['Total'] - df2['Tempe School District']

# df2.sort_values(by = 'Not Tempe', ascending = False)

# %%
df2 = df[df['Attending LEA ID'] == 4267]\
    .groupby(['School Name','School ID','Boundary District Name'])['Total ADM'].sum().unstack()

# %%
bdry_list = list(df[df['Attending LEA ID'] == 4267]['Boundary District Name'].unique())

# %%
df2['Total'] = df2.sum(axis = 1)

# %%
df2.reset_index(inplace = True)

# %%
df2['Bus'] = np.where(df2['School ID'].isin(bus_list), 1, 0)

# %%
df2['Not Kyrene'] = df2['Total'] - df2['Kyrene Elementary District'] #- df2['Other']

# %%
for c in ['Maricopa Unified School District','Roosevelt Elementary District']:
    display(df2.sort_values(by = [c], ascending = False).head(10)[['School Name', 'School ID', c]])
# Out:
# Boundary District Name                              School Name  School ID  \
# 1                              Kyrene Akimel A-Al Middle School       5298
# 5                                    Kyrene De Los Lagos School       5311
# 12                      Kyrene de la Estrella Elementary School      78923
# 23                                           Kyrene del Milenio      79143
# 6                                        Kyrene Digital Academy    1001168
# 3                                  Kyrene Aprende Middle School       5296
# 25                              Kyrene del Pueblo Middle School       5300
# 0                                           C I Waggoner School       5302
# 2                                 Kyrene Altadena Middle School       5297
# 4                               Kyrene Centennial Middle School       5299
#
# Boundary District Name  Maricopa Unified School District
# 1                                               123.0796
# 5                                                46.6480
# 12                                               31.5001
# 23                                               29.3338
# 6                                                29.0195
# 3                                                12.0000
# 25                                               12.0000
# 0                                                    NaN
# 2                                                    NaN
# 4                                                    NaN
# Boundary District Name                      School Name  School ID  \
# 4                       Kyrene Centennial Middle School       5299
# 18                           Kyrene de las Lomas School       5304
# 7                                  Kyrene Middle School       5301
# 6                                Kyrene Digital Academy    1001168
# 24                              Kyrene del Norte School       5303
# 10                           Kyrene de la Colina School       5308
# 21                           Kyrene de los Ninos School       5305
# 19                         Kyrene de las Manitas School       5318
# 0                                   C I Waggoner School       5302
# 25                      Kyrene del Pueblo Middle School       5300
#
# Boundary District Name  Roosevelt Elementary District
# 4                                             98.7018
# 18                                            83.6972
# 7                                             67.6927
# 6                                             33.6265
# 24                                            32.4700
# 10                                            31.9748
# 21                                            31.2200
# 19                                            24.5243
# 0                                             22.0000
# 25                                            18.4513

# %% [markdown]
# ## Load ZIP code level movement

# %%
df3 = pd.read_excel(os.path.join(data,"FY 2022 Open Enrollment Data.xlsx"), 
                   sheet_name = "School by Zip", skiprows = 1)

# %% [markdown]
# ## Which zipcodes are Roosevelt?

# %%
roosevelt = district_intersect_zip[(district_intersect_zip['NAME'].str.contains("Roosevelt")) & (district_intersect_zip['pct_overlap'] >= .5)]

# %%
district_intersect_zip[district_intersect_zip['NAME'].str.contains("Roosevelt")]\
    [['ZCTA5CE20','zip_area','district_area','district_intersect_zip_area','pct_overlap']].sort_values(by = 'pct_overlap', ascending = False)
# Out:
#     ZCTA5CE20    zip_area  district_area  district_intersect_zip_area  \
# 705     85040   10.110554      33.195685                     8.036089
# 544     85041   16.017308      33.195685                    12.349832
# 546     85042   19.437130      33.195685                     9.979136
# 198     85034   11.580681      33.195685                     1.015418
# 626     85007    4.619769      33.195685                     0.305505
# 474     85339  258.545773      33.195685                     1.509705
#
#      pct_overlap
# 705     0.794822
# 544     0.771030
# 546     0.513406
# 198     0.087682
# 626     0.066130
# 474     0.005839

# %%
roosevelt_zip = ['85040','85041','85042']

# %%
temp = df3[df3['Zip Code'].isin(roosevelt_zip)].groupby(['Attending LEA ID',
                                                         'Attending LEA Name',
                                                         'Zip Code'])['Total ADM'].sum().unstack()\
                                                        .sort_values(by = '85042', ascending = False)

# %%
temp = temp.reset_index()

# %%
temp['Attending LEA ID'] = temp['Attending LEA ID'].astype(int)

# %%
temp['Grades'] = temp['Attending LEA ID'].map(ctd_adm_grade_dict)

# %%
temp.head(10)

temp2 = temp[~ temp['Grades'].str.contains("12")]

for c in ['85040', '85041', '85042']:
    exec(f'''temp2['{c}_pct'] = temp2['{c}']/temp2['{c}'].sum()''')
# Out:
# <string>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
temp2['Entity Type'] = temp2['Attending LEA ID'].map(ctd_adm_type_dict)
# Out:
# C:\Users\matto\AppData\Local\Temp\ipykernel_11228\1309276490.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp2['Entity Type'] = temp2['Attending LEA ID'].map(ctd_adm_type_dict)

# %%
temp2.groupby(['Entity Type'])[['85040_pct','85041_pct','85042_pct']].sum()
# Out:
# Zip Code        85040_pct  85041_pct  85042_pct
# Entity Type
# Charter Holder   0.344744   0.303736   0.265153
# District         0.655256   0.696264   0.734847

# %%
temp2['total'] = temp2[['85040','85041','85042']].sum(axis = 1)
# Out:
# C:\Users\matto\AppData\Local\Temp\ipykernel_11228\1543417943.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp2['total'] = temp2[['85040','85041','85042']].sum(axis = 1)

# %%
temp2.sort_values(by = ['total'], ascending = False)
# Out:
# Zip Code  Attending LEA ID                                 Attending LEA Name  \
# 0                     4279                      Roosevelt Elementary District
# 1                     4258                              Tempe School District
# 52                    4276                         Laveen Elementary District
# 5                     4267                         Kyrene Elementary District
# 7                    78783                Fit Kids, Inc. dba Champion Schools
# 14                    4340                 Phoenix Education Management, LLC,
# 22                   91763         Legacy Traditional School – Laveen Village
# 30                   90192                     Morrison Education Group, Inc.
# 24                   92250               Espiritu Community Development Corp.
# 15                   90878     Academy of Mathematics and Science South, Inc.
# 27                   89850                 EAGLE South Mountain Charter, Inc.
# 25                    4256                        Phoenix Elementary District
# 23                  549803                        BASIS Charter Schools, Inc.
# 12                   79233  Kaizen Education Foundation dba South Pointe E...
# 8                    91108                         South Phoenix Academy Inc.
# 10                   90540                         South Valley Academy, Inc.
# 31                   90884                   George Gervin Youth Center, Inc.
# 19                   78965  Kaizen Education Foundation dba South Pointe J...
# 42                    4303                               Friendly House, Inc.
# 29                   91170                    EAGLE College Prep Harmony, LLC
# 43                   90273                            ASU Preparatory Academy
# 51                   91948                    Vista College Preparatory, Inc.
# 33                   92325                            ASU Preparatory Academy
# 39                   89949                            ASU Preparatory Academy
# 65                   91329          Kaizen Education Foundation dba Advance U
# 66                   92716                            ASU Preparatory Academy
# 63                   90036      West Valley Arts and Technology Academy, Inc.
# 47                   92349                        BASIS Charter Schools, Inc.
# 46                   92620            Horizon Community Learning Center, Inc.
# 55                    4262                         Osborn Elementary District
#
# Zip Code      85040      85041      85042 Grades  85040_pct  85041_pct  \
# 0         1481.2278  3316.2541  1299.2307  'PK-8   0.418806   0.441081
# 1          731.9586    25.7436   996.1395  'PK-8   0.206956   0.003424
# 52              NaN  1578.0816    10.8247  'PK-8        NaN   0.209894
# 5           48.3650   127.3004   323.7994  'PK-8   0.013675   0.016932
# 7           53.5919   216.4635   154.0858   'K-8   0.015153   0.028791
# 14         290.3663    55.4826    59.9472   'K-8   0.082099   0.007380
# 22              NaN   329.6662    43.7063   'K-8        NaN   0.043848
# 30              NaN   345.9625    27.1748   'K-8        NaN   0.046015
# 24         190.0746   129.7250    35.9500   'K-6   0.053742   0.017254
# 15          40.0807   236.1208    55.2515   'K-8   0.011333   0.031405
# 27              NaN   293.9561    32.1758   'K-8        NaN   0.039098
# 25          55.9486   176.9533    33.2500  'PK-8   0.015819   0.023536
# 23          25.9426   175.5039    41.7667   'K-6   0.007335   0.023343
# 12         122.0361    52.0221    67.0088   'K-6   0.034505   0.006919
# 8           68.8098    38.8550   130.6756   'K-4   0.019455   0.005168
# 10          49.4212    39.2621   114.4488   '5-8   0.013973   0.005222
# 31          92.7045    15.5915    26.2000   'K-8   0.026212   0.002074
# 19          39.9049    36.7200    46.3100   '6-8   0.011283   0.004884
# 42          28.0028    73.2200    13.7350   'K-8   0.007918   0.009739
# 29          86.0798        NaN    27.7235   'K-8   0.024338        NaN
# 43          35.3453    53.2356    13.0000   '3-6   0.009994   0.007081
# 51          26.0591    45.5591    10.9900   'K-8   0.007368   0.006060
# 33          20.5159    38.1242    21.0341   '5-8   0.005801   0.005071
# 39          16.8400    27.4900    15.5200   'K-4   0.004761   0.003656
# 65          18.5650    21.4200        NaN   'K-3   0.005249   0.002849
# 66          14.9430    16.2095        NaN   'K-4   0.004225   0.002156
# 63              NaN    27.8758        NaN   'K-8        NaN   0.003708
# 47              NaN    15.1667    12.1000   'K-5        NaN   0.002017
# 46              NaN        NaN    12.1700   'K-6        NaN        NaN
# 55              NaN    10.5000        NaN  'PK-8        NaN   0.001397
#
# Zip Code  85042_pct     Entity Type      total
# 0          0.358486        District  6096.7126
# 1          0.274856        District  1753.8417
# 52         0.002987        District  1588.9063
# 5          0.089343        District   499.4648
# 7          0.042516  Charter Holder   424.1412
# 14         0.016541  Charter Holder   405.7961
# 22         0.012060  Charter Holder   373.3725
# 30         0.007498  Charter Holder   373.1373
# 24         0.009919  Charter Holder   355.7496
# 15         0.015245  Charter Holder   331.4530
# 27         0.008878  Charter Holder   326.1319
# 25         0.009174        District   266.1519
# 23         0.011524  Charter Holder   243.2132
# 12         0.018489  Charter Holder   241.0670
# 8          0.036056  Charter Holder   238.3404
# 10         0.031579  Charter Holder   203.1321
# 31         0.007229  Charter Holder   134.4960
# 19         0.012778  Charter Holder   122.9349
# 42         0.003790  Charter Holder   114.9578
# 29         0.007650  Charter Holder   113.8033
# 43         0.003587  Charter Holder   101.5809
# 51         0.003032  Charter Holder    82.6082
# 33         0.005804  Charter Holder    79.6742
# 39         0.004282  Charter Holder    59.8500
# 65              NaN  Charter Holder    39.9850
# 66              NaN  Charter Holder    31.1525
# 63              NaN  Charter Holder    27.8758
# 47         0.003339  Charter Holder    27.2667
# 46         0.003358  Charter Holder    12.1700
# 55              NaN        District    10.5000

# %%
district_intersect_zip.columns
# Out:
# Index(['STATEFP', 'ELSDLEA', 'GEOID', 'NAME', 'LSAD', 'LOGRADE', 'HIGRADE',
#        'MTFCC', 'SDTYP', 'FUNCSTAT', 'ALAND', 'AWATER', 'INTPTLAT', 'INTPTLON',
#        'GEO_YEAR', 'SCHOOLYEAR', 'UNSDLEA', 'district_area', 'ZCTA5CE20',
#        'GEOID20', 'CLASSFP20', 'MTFCC20', 'FUNCSTAT20', 'ALAND20', 'AWATER20',
#        'INTPTLAT20', 'INTPTLON20', 'zip_area', 'geometry',
#        'district_intersect_zip_area', 'pct_overlap'],
#       dtype='object')

# %%
roosevelt = district_intersect_zip[(district_intersect_zip['NAME'].str.contains("Roosevelt"))
                       & (district_intersect_zip['ZCTA5CE20'].isin(roosevelt_zip))]

roosevelt_zips = district_intersect_zip[(district_intersect_zip['ZCTA5CE20'].isin(roosevelt_zip))]

# %%
roosevelt["center"] = roosevelt["geometry"].centroid
roosevelt_points = roosevelt.copy()
roosevelt_points.set_geometry("center", inplace = True)
# Out:
# C:\Users\matto\AppData\Local\Temp\ipykernel_11228\1218497279.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   roosevelt["center"] = roosevelt["geometry"].centroid
# C:\Users\matto\anaconda3\envs\Python_3_11\Lib\site-packages\geopandas\geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
## Roosevelt Schools

# %%
roosevelt_schools = gpd.sjoin(edge_gdf[~ edge_gdf['LEA Grade'].str.contains("12", na = False)], roosevelt)

roosevelt_schools.plot()
# Out:
# <Axes: >

# %%
ax = roosevelt.plot(color="white", edgecolor="black", linewidth = 1, figsize=(18, 10))

for x, y, label in zip(roosevelt_points.geometry.x, roosevelt_points.geometry.y, roosevelt_points['ZCTA5CE20']):
    ax.annotate(label, xy=(x, y), xytext=(3, 3), textcoords="offset points", fontsize = 18, weight = 'bold')
    
roosevelt_schools.plot(ax=ax, column = 'LEA Type', cmap = 'RdBu')

print(roosevelt_schools['School Name'].unique())

roosevelt_schools['School Name'] = roosevelt_schools['School Name'].str.replace("School","")
roosevelt_schools['School Name'] = roosevelt_schools['School Name'].str.replace("Schools","")
roosevelt_schools['School Name'] = roosevelt_schools['School Name'].str.replace("Elementary","")
roosevelt_schools['School Name'] = roosevelt_schools['School Name'].str.strip()

# roosevelt_schools['School Name'] = roosevelt_schools['School Name'].str.replace("South Phoenix Prep and Arts Academy","South Phoenix Prep and Arts ")

print(roosevelt_schools['School Name'].unique())

for x, y, label in zip(roosevelt_schools.geometry.x, roosevelt_schools.geometry.y, roosevelt_schools['School Name']):
    if label not in (['South Phoenix Prep and Arts Academy','ASU Preparatory Academy - South Phoenix Primary']):
        ax.annotate(label, xy=(x, y), xytext=(2, 2), textcoords="offset points", fontsize = 9)

# gpd.sjoin(roosevelt, edge_gdf[~ edge_gdf['LEA Grade'].str.contains("12", na = False)])\
#     .groupby(['ZCTA5CE20','LEA Type']).size().unstack()

# gpd.sjoin(roosevelt, edge_gdf[~ edge_gdf['LEA Grade'].str.contains("12", na = False)])\
#     .groupby(['ZCTA5CE20','LEA Type','LEA Name']).size()\
#     .unstack().transpose().fillna(0)
# Out:
# ['Academy of Math and Science South Mountain' 'BASIS Phoenix South'
#  'Bernard Black Elementary School' 'C J Jorgensen School'
#  'EAGLE College Prep' 'Ed & Verma Pastor Elementary School'
#  'Ignacio Conchos School' 'John R Davis School'
#  'Southwest Elementary School' 'Sun Valley Academy'
#  'Sunland Elementary School' 'V H Lassen Elementary School'
#  'Valley View School' 'Victory High School - West Campus'
#  'Amy L. Houston Academy' 'C O Greenfield School' 'Champion Schools'
#  'Cloves C Campbell Sr Elementary School' 'George Gervin Prep Academy'
#  'iAmRSDOnline Academy' 'John F Kennedy Elementary School'
#  'Kaizen Education Foundation dba South Pointe Elementary Scho'
#  'Maxine O Bush Elementary School' 'South Phoenix Prep and Arts Academy'
#  'South Pointe Junior High School' 'South Valley Prep and Arts School'
#  'T G Barr School' 'ASU Preparatory Academy - South Phoenix Intermediate'
#  'ASU Preparatory Academy - South Phoenix Primary'
#  'Cesar E Chavez Community School' 'EAGLE College Prep Phoenix South'
#  'Irene Lopez School' 'Martin Luther King Early Childhood Center'
#  'Percy L Julian School' 'Pioneer Technology & Arts Academy of Arizona'
#  'Reyes Maria Ruiz Leadership Academy'
#  'South Mountain Preparatory Academy']
# ['Academy of Math and Science South Mountain' 'BASIS Phoenix South'
#  'Bernard Black' 'C J Jorgensen' 'EAGLE College Prep' 'Ed & Verma Pastor'
#  'Ignacio Conchos' 'John R Davis' 'Southwest' 'Sun Valley Academy'
#  'Sunland' 'V H Lassen' 'Valley View' 'Victory High  - West Campus'
#  'Amy L. Houston Academy' 'C O Greenfield' 'Champion s'
#  'Cloves C Campbell Sr' 'George Gervin Prep Academy'
#  'iAmRSDOnline Academy' 'John F Kennedy'
#  'Kaizen Education Foundation dba South Pointe  Scho' 'Maxine O Bush'
#  'South Phoenix Prep and Arts Academy' 'South Pointe Junior High'
#  'South Valley Prep and Arts' 'T G Barr'
#  'ASU Preparatory Academy - South Phoenix Intermediate'
#  'ASU Preparatory Academy - South Phoenix Primary'
#  'Cesar E Chavez Community' 'EAGLE College Prep Phoenix South'
#  'Irene Lopez' 'Martin Luther King Early Childhood Center'
#  'Percy L Julian' 'Pioneer Technology & Arts Academy of Arizona'
#  'Reyes Maria Ruiz Leadership Academy'
#  'South Mountain Preparatory Academy']

# %%
df3.columns
# Out:
# Index(['Attending LEA ID', 'Attending LEA Name', 'School Id', 'School Name',
#        'Zip Code', 'Total ADM'],
#       dtype='object')

# %%
df3['grade'] = df3['Attending LEA ID'].map(ctd_adm_grade_dict)

df3[(df3['Zip Code'].isin(roosevelt_zip)) & (~ df3['grade'].str.contains("12", na = False))]\
    .groupby(['Attending LEA Name','School Name','Zip Code'])['Total ADM'].sum().unstack()\
    .sort_values(by = '85042', ascending = False).head(20)
# Out:
# Zip Code                                                                                                  85040  \
# Attending LEA Name                                 School Name
# Tempe School District                              Nevitt Elementary School                            128.7902
# Roosevelt Elementary District                      C O Greenfield School                               162.5888
#                                                    Cloves C Campbell Sr Elementary School              113.1878
# Tempe School District                              Gililland Middle School                             224.1599
# Roosevelt Elementary District                      Maxine O Bush Elementary School                          NaN
#                                                    T G Barr School                                      87.9450
#                                                    John F Kennedy Elementary School                    114.5946
# Fit Kids, Inc. dba Champion Schools                Champion Schools                                     53.5919
# South Phoenix Academy Inc.                         South Phoenix Prep and Arts Academy                  68.8098
# South Valley Academy, Inc.                         South Valley Prep and Arts School                    49.4212
# Tempe School District                              Fees College Preparatory Middle School               18.9100
#                                                    Frank Elementary School                                  NaN
# Kyrene Elementary District                         Kyrene Centennial Middle School                      16.0000
# Kaizen Education Foundation dba South Pointe El... Kaizen Education Foundation dba South Pointe El...  122.0361
# Kyrene Elementary District                         Kyrene de las Lomas School                           19.9550
# Roosevelt Elementary District                      Valley View School                                   15.2026
# Phoenix Education Management, LLC,                 Pioneer Technology & Arts Academy of Arizona        290.3663
# Academy of Mathematics and Science South, Inc.     Academy of Math and Science South Mountain           40.0807
# Kaizen Education Foundation dba South Pointe Ju... South Pointe Junior High School                      39.9049
# Legacy Traditional School – Laveen Village         Legacy Traditional School – Laveen Village               NaN
#
# Zip Code                                                                                                  85041  \
# Attending LEA Name                                 School Name
# Tempe School District                              Nevitt Elementary School                             14.0036
# Roosevelt Elementary District                      C O Greenfield School                                28.2299
#                                                    Cloves C Campbell Sr Elementary School               25.2849
# Tempe School District                              Gililland Middle School                                  NaN
# Roosevelt Elementary District                      Maxine O Bush Elementary School                      36.5400
#                                                    T G Barr School                                      27.0850
#                                                    John F Kennedy Elementary School                     21.9200
# Fit Kids, Inc. dba Champion Schools                Champion Schools                                    216.4635
# South Phoenix Academy Inc.                         South Phoenix Prep and Arts Academy                  38.8550
# South Valley Academy, Inc.                         South Valley Prep and Arts School                    39.2621
# Tempe School District                              Fees College Preparatory Middle School               11.7400
#                                                    Frank Elementary School                                  NaN
# Kyrene Elementary District                         Kyrene Centennial Middle School                      28.1615
# Kaizen Education Foundation dba South Pointe El... Kaizen Education Foundation dba South Pointe El...   52.0221
# Kyrene Elementary District                         Kyrene de las Lomas School                           21.5000
# Roosevelt Elementary District                      Valley View School                                  391.3938
# Phoenix Education Management, LLC,                 Pioneer Technology & Arts Academy of Arizona         55.4826
# Academy of Mathematics and Science South, Inc.     Academy of Math and Science South Mountain          236.1208
# Kaizen Education Foundation dba South Pointe Ju... South Pointe Junior High School                      36.7200
# Legacy Traditional School – Laveen Village         Legacy Traditional School – Laveen Village          329.6662
#
# Zip Code                                                                                                  85042
# Attending LEA Name                                 School Name
# Tempe School District                              Nevitt Elementary School                            402.2272
# Roosevelt Elementary District                      C O Greenfield School                               286.3921
#                                                    Cloves C Campbell Sr Elementary School              235.4096
# Tempe School District                              Gililland Middle School                             215.3732
# Roosevelt Elementary District                      Maxine O Bush Elementary School                     209.0829
#                                                    T G Barr School                                     196.6654
#                                                    John F Kennedy Elementary School                    163.7508
# Fit Kids, Inc. dba Champion Schools                Champion Schools                                    154.0858
# South Phoenix Academy Inc.                         South Phoenix Prep and Arts Academy                 130.6756
# South Valley Academy, Inc.                         South Valley Prep and Arts School                   114.4488
# Tempe School District                              Fees College Preparatory Middle School               91.2299
#                                                    Frank Elementary School                              89.0128
# Kyrene Elementary District                         Kyrene Centennial Middle School                      78.6213
# Kaizen Education Foundation dba South Pointe El... Kaizen Education Foundation dba South Pointe El...   67.0088
# Kyrene Elementary District                         Kyrene de las Lomas School                           62.3357
# Roosevelt Elementary District                      Valley View School                                   60.9282
# Phoenix Education Management, LLC,                 Pioneer Technology & Arts Academy of Arizona         59.9472
# Academy of Mathematics and Science South, Inc.     Academy of Math and Science South Mountain           55.2515
# Kaizen Education Foundation dba South Pointe Ju... South Pointe Junior High School                      46.3100
# Legacy Traditional School – Laveen Village         Legacy Traditional School – Laveen Village           43.7063

# %%
district_intersect_zip[district_intersect_zip['ZCTA5CE20'].isin(roosevelt_zip)].plot(figsize = (18,10))
# Out:
# <Axes: >

# %% [markdown]
# ## Roosevelt Zipcodes

# %%
# zip_shape.to_crs('EPSG:4269',inplace = True)

ax = zip_shape[zip_shape['ZCTA5CE20'].isin(roosevelt_zip)].plot(color = 'white', edgecolor = 'black', figsize = (18,10))

roosevelt.plot(ax=ax, edgecolor = 'black')

for x, y, label in zip(roosevelt_points.geometry.x, roosevelt_points.geometry.y, roosevelt_points['ZCTA5CE20']):
    ax.annotate(label, xy=(x, y), xytext=(3, 3), textcoords="offset points", fontsize = 18, weight = 'bold')
    
roosevelt_zip_schools = gpd.sjoin(edge_gdf[~ edge_gdf['LEA Grade'].str.contains("12", na = False)], roosevelt_zips)

roosevelt_zip_schools.plot(ax = ax, column = 'LEA Type', cmap = 'RdBu')
# Out:
# <Axes: >

# %%
kyrene = district_intersect_zip[(district_intersect_zip['NAME'].str.contains("Kyrene")) & (district_intersect_zip['pct_overlap'] >= .4)]

kyrene_zip = list(kyrene['ZCTA5CE20'].unique())

kyrene["center"] = kyrene["geometry"].centroid
kyrene_points = kyrene.copy()
kyrene_points.set_geometry("center", inplace = True)
# Out:
# C:\Users\matto\AppData\Local\Temp\ipykernel_11228\39400137.py:5: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   kyrene["center"] = kyrene["geometry"].centroid
# C:\Users\matto\anaconda3\envs\Python_3_11\Lib\site-packages\geopandas\geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
ax = zip_shape[(zip_shape['ZCTA5CE20'].isin(kyrene_zip)) | ((zip_shape['ZCTA5CE20'].isin(roosevelt_zip)))].plot(color = 'white', edgecolor = 'black', figsize = (18,10))

for x, y, label in zip(kyrene_points.geometry.x, kyrene_points.geometry.y, kyrene_points['ZCTA5CE20']):
    ax.annotate(label, xy=(x, y), xytext=(3, 3), textcoords="offset points", fontsize = 18, weight = 'bold')

# %%
kyrene_schools = gpd.sjoin(edge_gdf[~ edge_gdf['LEA Grade'].str.contains("12", na = False)], kyrene)

kyrene_schools.plot()
# Out:
# <Axes: >

# %%
bus_schools = kyrene_schools[kyrene_schools['State School ID'].astype(int).isin(bus_list)]

# %%
zip_shape.to_crs('EPSG:4269', inplace = True)

# %%
district_shape.to_crs('EPSG:4269', inplace = True)

# %%
district_shape[district_shape['NAME'].str.contains("Roosevelt|Kyrene")].plot()
# Out:
# <Axes: >

# %%
ax = district_shape[district_shape['NAME'].str.contains("Roosevelt|Kyrene")].plot(color = 'lightgreen', 
                                                                             edgecolor = 'black', alpha = .8, 
                                                                                  linewidth = 3, figsize = (18,10))


zip_shape[(zip_shape['ZCTA5CE20'].isin(kyrene_zip)) | ((zip_shape['ZCTA5CE20'].isin(roosevelt_zip)))]\
    .plot(color = 'white', edgecolor = 'black', ax = ax, linestyle='--', alpha = .6)

ax.set_title("Roosevelt and Kyrene Zip Codes")


for x, y, label in zip(roosevelt_points.geometry.x, roosevelt_points.geometry.y, roosevelt_points['ZCTA5CE20']):
    ax.annotate(label, xy=(x, y), xytext=(3, 3), textcoords="offset points", fontsize = 12, weight = 'bold')
    
for x, y, label in zip(kyrene_points.geometry.x, kyrene_points.geometry.y, kyrene_points['ZCTA5CE20']):
    ax.annotate(label, xy=(x, y), xytext=(3, 3), textcoords="offset points", fontsize = 12, weight = 'bold')

kyrene_schools.plot(ax = ax, color = 'red')
roosevelt_schools.plot(ax = ax, color = 'black')
bus_schools.plot(ax = ax, color = 'green')
# Out:
# <Axes: title={'center': 'Roosevelt and Kyrene Zip Codes'}>

# %%
df.columns
# Out:
# Index(['Attending LEA ID', 'Attending LEA Name', 'School ID', 'School Name',
#        'Boundary District ID', 'Boundary District Name', 'Total ADM'],
#       dtype='object')

# %%
top_roosevelt_destinations = df[(df['Boundary District ID'] == 4279) & (df['Attending LEA ID'].isin([4267,4258]))]\
    .groupby(['School Name','Attending LEA Name'])['Total ADM'].sum().sort_values(ascending = False).to_frame().reset_index()

top_destinations = list(top_roosevelt_destinations['School Name'])

# %%
df3
# Out:
#        Attending LEA ID               Attending LEA Name  School Id  \
# 0               1000166               A+ Charter Schools    1000972
# 1               1000166               A+ Charter Schools    1000972
# 2               1000166               A+ Charter Schools    1000972
# 3                 90199            Academy Del Sol, Inc.      90200
# 4                 90199            Academy Del Sol, Inc.      90200
# ...                 ...                              ...        ...
# 11594              4507  Yuma Union High School District       6189
# 11595              4507  Yuma Union High School District       6189
# 11596              4507  Yuma Union High School District       6189
# 11597              4507  Yuma Union High School District      91316
# 11598              4507  Yuma Union High School District      91316
#
#                         School Name Zip Code  Total ADM  grade
# 0                A+ Charter Schools    85138   180.9777  '7-12
# 1                A+ Charter Schools    85139    60.7659  '7-12
# 2                A+ Charter Schools    Other     3.9821  '7-12
# 3                   Academy Del Sol    85705   109.5793   'K-8
# 4                   Academy Del Sol    Other    54.3089   'K-8
# ...                             ...      ...        ...    ...
# 11594              Yuma High School    85365    59.8398  '9-12
# 11595              Yuma High School    Other    17.3300  '9-12
# 11596              Yuma High School    85350    12.5242  '9-12
# 11597  Yuma Online Distance Academy    Other    28.5556  '9-12
# 11598  Yuma Online Distance Academy    85364    25.2041  '9-12
#
# [11599 rows x 7 columns]

# %%
df3[(df3['Zip Code'].isin(roosevelt_zip)) & (~ df3['grade'].str.contains('12', na = False))]\
    .groupby(['Attending LEA Name','School Name','Zip Code'])['Total ADM'].sum().unstack().reset_index()\
    .merge(top_roosevelt_destinations).sort_values(by = 'Total ADM', ascending = False)
# Out:
#             Attending LEA Name                               School Name  \
# 19       Tempe School District                  Nevitt Elementary School
# 2   Kyrene Elementary District           Kyrene Centennial Middle School
# 6   Kyrene Elementary District                Kyrene de las Lomas School
# 4   Kyrene Elementary District                      Kyrene Middle School
# 3   Kyrene Elementary District                    Kyrene Digital Academy
# 9   Kyrene Elementary District                   Kyrene del Norte School
# 5   Kyrene Elementary District                Kyrene de la Colina School
# 8   Kyrene Elementary District                Kyrene de los Ninos School
# 16       Tempe School District                   Gililland Middle School
# 15       Tempe School District    Fees College Preparatory Middle School
# 7   Kyrene Elementary District              Kyrene de las Manitas School
# 18       Tempe School District  McKemy Academy of International  Studies
# 0   Kyrene Elementary District                       C I Waggoner School
# 24       Tempe School District                               Wood School
# 20       Tempe School District                   Rover Elementary School
# 17       Tempe School District                Holdeman Elementary School
# 10  Kyrene Elementary District           Kyrene del Pueblo Middle School
# 21       Tempe School District                 Scales Technology Academy
# 12       Tempe School District                Broadmor Elementary School
# 13       Tempe School District                          Carminati School
# 1   Kyrene Elementary District          Kyrene Akimel A-Al Middle School
# 11       Tempe School District                            Aguilar School
# 23       Tempe School District                  Ward Traditional Academy
# 22       Tempe School District         Tempe Elementary Online Community
# 14       Tempe School District                    Connolly Middle School
#
#        85040    85041     85042  Total ADM
# 19  128.7902  14.0036  402.2272   101.6762
# 2    16.0000  28.1615   78.6213    98.7018
# 6    19.9550  21.5000   62.3357    83.6972
# 4    12.4100  25.7800   40.5727    67.6927
# 3        NaN  18.8889   17.9784    33.6265
# 9        NaN  10.4700   31.0000    32.4700
# 5        NaN  11.5000   23.8548    31.9748
# 8        NaN      NaN   17.0500    31.2200
# 16  224.1599      NaN  215.3732    30.2200
# 15   18.9100  11.7400   91.2299    25.7400
# 7        NaN      NaN   18.8443    24.5243
# 18   22.8033      NaN   39.1431    23.8033
# 0        NaN      NaN   19.0000    22.0000
# 24   75.1814      NaN   14.5000    19.5214
# 20       NaN      NaN   18.1750    19.3997
# 17  144.0475      NaN   16.9700    19.3600
# 10       NaN      NaN   14.5422    18.4513
# 21   57.8144      NaN   13.8300    18.3650
# 12   17.4087      NaN       NaN    16.4087
# 13   12.7250      NaN       NaN    16.3950
# 1        NaN  11.0000       NaN    16.0000
# 11       NaN      NaN   13.3700    13.3100
# 23       NaN      NaN   24.6000    13.1000
# 22   17.7982      NaN   21.9680    12.1725
# 14   12.3200      NaN   22.6578    11.3900
